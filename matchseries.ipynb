# %%
from pyiron_experimental import Project

# %%
pr = Project('test')

# %%
pr.remove_jobs_silently(recursive=True)

# %%
job = pr.create_job(job_type=pr.job_type.MatchSeries, job_name="toy")

# %%
job.input
# Out:
#                                                       Parameter  \
# 0                                              deformationModel
# 1                                            reduceDeformations
# 2                                           templateNamePattern
# 3                                             templateNumOffset
# 4                                               templateNumStep
# 5                                                  numTemplates
# 6                                                     cropInput
# 7                                                    cropStartX
# 8                                                    cropStartY
# 9                                     dontResizeOrCropReference
# 10                                               preSmoothSigma
# 11                                              saveRefAndTempl
# 12                                               numExtraStages
# 13                                                saveDirectory
# ...

# %%
job.input["templateNamePattern"] = "testImg_%d_STEM.tif"

# %%
job.run()
# Out:
# The job toy was saved and received the ID: 1

# %%
pr.job_table()
# Out:
#    id    status chemicalformula  job subjob    projectpath project  \
# 0   1  finished            None  toy   /toy  /home/jovyan/   test/
#
#                    timestart                   timestop  totalcputime  \
# 0 2020-09-10 17:17:33.746283 2020-09-10 17:18:46.947339          73.0
#
#                                                             computer  \
# 0  pyiron@jupyter-jan-2djanssen-2dpyiron-5fexperimental-2da4j6bv2z#1
#
#      hamilton hamversion parentid masterid
# 0  GenericJob        0.4     None     None

# %%
job["output.log"]
# Out:
# ['Created directory results/\n',
#  'reading reference image from: testImg_0_STEM.tif\n',
#  'reading template image from: testImg_0_STEM.tif\n',
#  'Created directory results/stage1/\n',
#  'Using templates images ---------------------------------------\n',
#  'testImg_1_STEM.tif\n',
#  'testImg_2_STEM.tif\n',
#  'testImg_3_STEM.tif\n',
#  '--------------------------------------------------------------\n',
#  'Created directory results/stage1/0/\n',
#  '\n',
#  '--------------------------------------------------------\n',
#  'Registration on level 6 started\n',
#  '--------------------------------------------------------\n',
#  '\n',
#  'Initial energy: -0.237336046038\n',
#  '  1 steps, tau:    4.0000, sigma:  1.0000 energy: -0.755973821650\n',
#  '  2 steps, tau:    4.0000, sigma:  1.0000 energy: -0.855649652696\n',
#  '  3 steps, tau:    2.0000, sigma:  1.0000 energy: -0.869205300768\n',
#  '  4 steps, tau:    2.0000, sigma:  1.0000 energy: -0.872651849014\n',
# ...
